# %% [markdown]
# ##  Project Assignment - Specialist Certificate in Data Analytics Essentials- Robbie Pratt (Secondary Dataset)

# %% [markdown]
# ### 2.1. Your project should make use of the following - Web Scraping

# %% [markdown]
# #### 1.1. Import Python Packages

# %%
import pandas as pd

# %% [markdown]
# URL

# %%
url = 'https://autotraveler.ru/en/spravka/fuel-price-in-europe.html#.Y7rDpv7P25c.html'

# %% [markdown]
# ### Using pd.read_html() function to read HTML webpage

# %%
df = pd.read_html(url, header = 0)
df
# Out:
# [    â                 Country         E5 (Super)    E5 (Super Plus)  \
#  0     1                 Austria  â¬ 1.49 (+ 0.02)  â¬ 1.69 (+ 0.02)
#  1     2              Azerbaijan           â¬ 1.11  â¬ 1.27 (- 0.01)
#  2     3                 Albania  â¬ 1.54 (+ 0.01)                NaN
#  3     4                 Andorra           â¬ 1.49           â¬ 1.55
#  4     5                 Armenia           â¬ 1.07           â¬ 1.15
#  5     6                 Belarus  â¬ 0.84 (- 0.06)  â¬ 0.92 (- 0.06)
#  6     7                 Belgium  â¬ 1.76 (+ 0.08)  â¬ 1.95 (+ 0.08)
#  7     8                Bulgaria  â¬ 1.35 (- 0.02)  â¬ 1.55 (- 0.04)
#  8     9  Bosnia and Herzegovina  â¬ 1.42 (- 0.03)           â¬ 1.54
#  9    10           Great Britain  â¬ 1.78 (- 0.08)  â¬ 2.26 (- 0.04)
#  10   11                 Hungary  â¬ 1.65 (+ 0.07)  â¬ 1.71 (+ 0.04)
#  11   12                 Germany  â¬ 1.85 (+ 0.05)           â¬ 1.86
# ...
