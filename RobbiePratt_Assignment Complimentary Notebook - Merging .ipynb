# %% [markdown]
# ##  Project Assignment - Specialist Certificate in Data Analytics Essentials- Robbie Pratt (Secondary Dataset_2)

# %% [markdown]
# ### 3.4. Data Merging

# %%
import pandas as pd

# %%
df_articles=pd.read_csv('articles_community.csv')
df_articles
# Out:
#       Unnamed: 0                                           doc_body  \
# 0              3  Skip navigation Sign in SearchLoading...\r\n\r...
# 1              5  No Free Hunch Navigation * kaggle.com\r\n\r\n ...
# 2              7  ☰ * Login\r\n * Sign Up\r\n\r\n * Learning Pat...
# 3              8  DATALAYER: HIGH THROUGHPUT, LOW LATENCY AT SCA...
# 4             12  Skip navigation Sign in SearchLoading...\r\n\r...
# ...          ...                                                ...
# 1051        3266  PouchDB-find is a new API and syntax that allo...
# 1052        3268  We compare discriminative and generative learn...
# 1053        3272  Essays about data, building products and boots...
# 1054        3279                                                NaN
# 1055        3281  Homepage Follow Sign in / Sign up Homepage * H...
#
#                                         doc_description  \
# 0     Detect bad readings in real time using Python ...
# ...

# %%
df_userInteractions=pd.read_csv('user-item-interactions.csv')
df_userInteractions
# Out:
#        Unnamed: 0  article_id  \
# 0               0      1430.0
# 1               1      1314.0
# 2               2      1429.0
# 3               3      1338.0
# 4               4      1276.0
# ...           ...         ...
# 45988       47575      1324.0
# 45989       47576       142.0
# 45990       47577       233.0
# 45991       47578      1160.0
# 45992       47581        16.0
#
#                                                    title  \
# 0      using pixiedust for fast, flexible, and easier...
# 1           healthcare python streaming application demo
# 2             use deep learning for image classification
# 3              ml optimization using cognitive assistant
# 4              deploy your python model as a restful api
# ...                                                  ...
# 45988                 ibm watson facebook posts for 2015
# 45989  neural networks for beginners: popular types a...
# 45990     bayesian nonparametric models – stats and bots
# ...

# %%
df_merge = df_articles.merge(df_userInteractions,on='article_id')

# %%
print (df_merge.head())
# Out:
#    Unnamed: 0_x                                           doc_body  \
# 0             3  Skip navigation Sign in SearchLoading...\r\n\r...
# 1             3  Skip navigation Sign in SearchLoading...\r\n\r...
# 2             3  Skip navigation Sign in SearchLoading...\r\n\r...
# 3             3  Skip navigation Sign in SearchLoading...\r\n\r...
# 4             3  Skip navigation Sign in SearchLoading...\r\n\r...
#
#                                      doc_description  \
# 0  Detect bad readings in real time using Python ...
# 1  Detect bad readings in real time using Python ...
# 2  Detect bad readings in real time using Python ...
# 3  Detect bad readings in real time using Python ...
# 4  Detect bad readings in real time using Python ...
#
#                                        doc_full_name doc_status  article_id  \
# 0  Detect Malfunctioning IoT Sensors with Streami...       Live           0
# 1  Detect Malfunctioning IoT Sensors with Streami...       Live           0
# ...
