# %% [markdown]
# ##  Project Assignment - Specialist Certificate in Data Analytics Essentials- Robbie Pratt

# %% [markdown]
# #### 1.1. Import Python Packages

# %%
import pandas as pd
import re
import numpy as np
import matplotlib.pylab as plt
import matplotlib
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import seaborn as sns

# %% [markdown]
# #### 1.2. Import a CSV file into a Pandas DataFrame

# %%
df_BestBooks=pd.read_csv('BestBooksEver.csv')
df_BestBooks.head(3)
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                   2657.To_Kill_a_Mockingbird
#
#                                        title                 series  \
# 0                           The Hunger Games    The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
#
#                                       author  rating  \
# 0                            Suzanne Collins    4.33
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                 Harper Lee    4.28
#
#                                          description language           isbn  \
# 0  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English  9780439023481
# 1  There is a door at the end of a silent corrido...  English  9780439358071
# 2  The unforgettable novel of a childhood in a sl...  English  9999999999999
#
#                                               genres  \
# 0  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 2  ['Classics', 'Fiction', 'Historical Fiction', ...
#
#                                           characters  ... firstPublishDate  \
# 0  ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...  ...              NaN
# 1  ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...  ...         06/21/03
# 2  ['Scout Finch', 'Atticus Finch', 'Jem Finch', ...  ...         07/11/60
#
#                                               awards numRatings  \
# 0  ['Locus Award Nominee for Best Young Adult Boo...    6376780
# 1  ['Bram Stoker Award for Works for Young Reader...    2507623
# 2  ['Pulitzer Prize for Fiction (1961)', 'Audie A...    4501075
#
#                                       ratingsByStars likedPercent  \
# 0  ['3444695', '1921313', '745221', '171994', '93...         96.0
# 1  ['1593642', '637516', '222366', '39573', '14526']         98.0
# 2  ['2363896', '1333153', '573280', '149952', '80...         95.0
#
#                                              setting  \
# 0  ['District 12, Panem', 'Capitol, Panem', 'Pane...
# 1  ['Hogwarts School of Witchcraft and Wizardry (...
# 2               ['Maycomb, Alabama (United States)']
#
#                                             coverImg  bbeScore bbeVotes  price
# 0  https://i.gr-assets.com/images/S/compressed.ph...   2993816    30516   5.09
# 1  https://i.gr-assets.com/images/S/compressed.ph...   2632233    26923   7.38
# 2  https://i.gr-assets.com/images/S/compressed.ph...   2269402    23328    NaN
#
# [3 rows x 25 columns]

# %% [markdown]
# #### 1.3.  Web Scraping - Is in the complimentary notebook

# %% [markdown]
# #### 1.4. View Data

# %%
print(df_BestBooks.shape)
# Out:
# (52478, 25)

# %% [markdown]
# #### 1.5. Find missing values in the dataset

# %%
null = df_BestBooks.isna().sum()
print("Number of null values in the dataset are null: ", null)
# Out:
# Number of null values in the dataset are null:  bookId                  0
# title                   0
# series              29008
# author                  0
# rating                  0
# description          1338
# language             3806
# isbn                    0
# genres                  0
# characters              0
# bookFormat           1473
# edition             47523
# pages                2347
# publisher            3696
# publishDate           880
# firstPublishDate    21326
# awards                  0
# numRatings              0
# ratingsByStars          0
# likedPercent          622
# setting                 0
# coverImg              605
# bbeScore                0
# bbeVotes                0
# price               14365
# dtype: int64

# %% [markdown]
# Columns that were not needed and had a lot of missing values, were dropped.

# %%
df_BestBooks = df_BestBooks.drop(columns = ['series', 'description', 'language', 'bookFormat', 'edition', 'pages', 'publisher', 'publishDate', 'firstPublishDate', 'coverImg'])

# %%
null = df_BestBooks.isnull().sum()
print("Number of null values in the dataset are null: ", null)
# Out:
# Number of null values in the dataset are null:  bookId                0
# title                 0
# author                0
# rating                0
# isbn                  0
# genres                0
# characters            0
# awards                0
# numRatings            0
# ratingsByStars        0
# likedPercent        622
# setting               0
# bbeScore              0
# bbeVotes              0
# price             14365
# dtype: int64

# %%
df_BestBooks.head(3)
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                   2657.To_Kill_a_Mockingbird
#
#                                        title  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 2                      To Kill a Mockingbird
#
#                                       author  rating           isbn  \
# 0                            Suzanne Collins    4.33  9780439023481
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50  9780439358071
# 2                                 Harper Lee    4.28  9999999999999
#
#                                               genres  \
# 0  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 2  ['Classics', 'Fiction', 'Historical Fiction', ...
#
#                                           characters  \
# 0  ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...
# 1  ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...
# 2  ['Scout Finch', 'Atticus Finch', 'Jem Finch', ...
#
#                                               awards  numRatings  \
# 0  ['Locus Award Nominee for Best Young Adult Boo...     6376780
# 1  ['Bram Stoker Award for Works for Young Reader...     2507623
# 2  ['Pulitzer Prize for Fiction (1961)', 'Audie A...     4501075
#
#                                       ratingsByStars  likedPercent  \
# 0  ['3444695', '1921313', '745221', '171994', '93...          96.0
# 1  ['1593642', '637516', '222366', '39573', '14526']          98.0
# 2  ['2363896', '1333153', '573280', '149952', '80...          95.0
#
#                                              setting  bbeScore  bbeVotes price
# 0  ['District 12, Panem', 'Capitol, Panem', 'Pane...   2993816     30516  5.09
# 1  ['Hogwarts School of Witchcraft and Wizardry (...   2632233     26923  7.38
# 2               ['Maycomb, Alabama (United States)']   2269402     23328   NaN

# %% [markdown]
# Drop rows with missing price as I will be doing linear regression comparing price and reviews.

# %%
df_BestBooks.dropna(axis=0, inplace=True)

# %%
null = df_BestBooks.isna().sum()
print("Number of null values in the dataset are null: ", null)
# Out:
# Number of null values in the dataset are null:  bookId            0
# title             0
# author            0
# rating            0
# isbn              0
# genres            0
# characters        0
# awards            0
# numRatings        0
# ratingsByStars    0
# likedPercent      0
# setting           0
# bbeScore          0
# bbeVotes          0
# price             0
# dtype: int64

# %%
print(df_BestBooks.shape)
# Out:
# (37901, 15)

# %%
null = df_BestBooks.isna().sum()
print("Number of null values in the dataset are null: ", null)
# Out:
# Number of null values in the dataset are null:  bookId               0
# title                0
# author               0
# rating               0
# isbn                 0
# genres               0
# characters           0
# awards               0
# numRatings           0
# ratingsByStars       0
# likedPercent         0
# setting              0
# bbeScore             0
# bbeVotes             0
# price               12
# Award_Count          0
# new_genre            0
# Error_rating         0
# Error_percentage     0
# dtype: int64

# %%
df_BestBooks.dropna(axis=0, inplace=True)

# %%
null = df_BestBooks.isna().sum()
print("Number of null values in the dataset are null: ", null)
# Out:
# Number of null values in the dataset are null:  bookId              0
# title               0
# author              0
# rating              0
# isbn                0
# genres              0
# characters          0
# awards              0
# numRatings          0
# ratingsByStars      0
# likedPercent        0
# setting             0
# bbeScore            0
# bbeVotes            0
# price               0
# Award_Count         0
# new_genre           0
# Error_rating        0
# Error_percentage    0
# dtype: int64

# %%
df_BestBooks.head(3)
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 4                               41865.Twilight
#
#                                        title  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 4                                   Twilight
#
#                                       author  rating           isbn  \
# 0                            Suzanne Collins    4.33  9780439023481
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50  9780439358071
# 4                            Stephenie Meyer    3.60  9780316015844
#
#                                               genres  \
# 0  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 4  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
#
#                                           characters  \
# 0  ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...
# 1  ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...
# 4  ['Edward Cullen', 'Jacob Black', 'Laurent', 'R...
#
#                                               awards  numRatings  \
# 0  ['Locus Award Nominee for Best Young Adult Boo...     6376780
# 1  ['Bram Stoker Award for Works for Young Reader...     2507623
# 4  ['Georgia Peach Book Award (2007)', 'Buxtehude...     4964519
#
#                                       ratingsByStars  likedPercent  \
# 0  ['3444695', '1921313', '745221', '171994', '93...          96.0
# 1  ['1593642', '637516', '222366', '39573', '14526']          98.0
# 4  ['1751460', '1113682', '1008686', '542017', '5...          78.0
#
#                                              setting  bbeScore  bbeVotes  \
# 0  ['District 12, Panem', 'Capitol, Panem', 'Pane...   2993816     30516
# 1  ['Hogwarts School of Witchcraft and Wizardry (...   2632233     26923
# 4  ['Forks, Washington (United States)', 'Phoenix...   1459448     14874
#
#    price  Award_Count   new_genre Error_rating Error_percentage
# 0   5.09           41  YoungAdult     No_Error         No_Error
# 1   7.38            9     Fantasy     No_Error         No_Error
# 4   2.10           25  YoungAdult     No_Error         No_Error

# %% [markdown]
# ### Awards is in a list, convert to string and count awards

# %% [markdown]
# df_BestBooks ['awards'] = df_BestBooks['awards'].str.replace(r'\W',"")

# %%
df_BestBooks.head(10)
# Out:
#                                          bookId  \
# 0                      2767052-the-hunger-games
# 1   2.Harry_Potter_and_the_Order_of_the_Phoenix
# 4                                41865.Twilight
# 5                          19063.The_Book_Thief
# 6                            170448.Animal_Farm
# 8             30.J_R_R_Tolkien_4_Book_Boxed_Set
# 9                      18405.Gone_with_the_Wind
# 12                       370493.The_Giving_Tree
# 13                       6185.Wuthering_Heights
# 15                      929.Memoirs_of_a_Geisha
#
#                                                 title  \
# 0                                    The Hunger Games
# 1           Harry Potter and the Order of the Phoenix
# 4                                            Twilight
# 5                                      The Book Thief
# 6                                         Animal Farm
# 8   J.R.R. Tolkien 4-Book Boxed Set: The Hobbit an...
# 9                                  Gone with the Wind
# 12                                    The Giving Tree
# 13                                  Wuthering Heights
# 15                                Memoirs of a Geisha
#
#                                                author  rating           isbn  \
# 0                                     Suzanne Collins    4.33  9780439023481
# 1           J.K. Rowling, Mary GrandPré (Illustrator)    4.50  9780439358071
# 4                                     Stephenie Meyer    3.60  9780316015844
# 5                     Markus Zusak (Goodreads Author)    4.37  9780375831003
# 6   George Orwell, Russell Baker (Preface), C.M. W...    3.95  9780451526342
# 8                                      J.R.R. Tolkien    4.60  9780345538376
# 9                                   Margaret Mitchell    4.30  9780446675536
# 12                                   Shel Silverstein    4.37  9780060256654
# 13  Emily Brontë, Richard J. Dunn (Editor), David ...    3.86  9780393978896
# 15                                      Arthur Golden    4.12  9781400096893
#
#                                                genres  \
# 0   ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1   ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 4   ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
# 5   ['Historical Fiction', 'Fiction', 'Young Adult...
# 6   ['Classics', 'Fiction', 'Dystopia', 'Fantasy',...
# 8   ['Fantasy', 'Fiction', 'Classics', 'Adventure'...
# 9   ['Classics', 'Historical Fiction', 'Fiction', ...
# 12  ['Childrens', 'Picture Books', 'Classics', 'Fi...
# 13  ['Classics', 'Fiction', 'Romance', 'Gothic', '...
# 15  ['Fiction', 'Historical Fiction', 'Romance', '...
#
#                                            characters  \
# 0   ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...
# 1   ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...
# 4   ['Edward Cullen', 'Jacob Black', 'Laurent', 'R...
# 5   ['Liesel Meminger', 'Hans Hubermann', 'Rudy St...
# 6   ['Snowball', 'Napoleon', 'Clover', 'Boxer', 'O...
# 8   ['Frodo Baggins', 'Gandalf', 'Bilbo Baggins', ...
# 9   ["Scarlett O'Hara", 'Rhett Butler', 'Ashley Wi...
# 12                                                 []
# 13  ['Heathcliff', 'Catherine Earnshaw', 'Edgar Li...
# 15  ['Sayuri Nitta', 'Mr. Bekku', 'Ichiro Tanaka',...
#
#                                                awards  numRatings  \
# 0   ['Locus Award Nominee for Best Young Adult Boo...     6376780
# 1   ['Bram Stoker Award for Works for Young Reader...     2507623
# 4   ['Georgia Peach Book Award (2007)', 'Buxtehude...     4964519
# 5   ['National Jewish Book Award for Children’s an...     1834276
# 6   ['Prometheus Hall of Fame Award (2011)', 'Retr...     2740713
# 8                                                  []      110146
# 9   ['Pulitzer Prize for Novel (1937)', 'National ...     1074620
# 12                                                 []      905731
# 13                                                 []     1342664
# 15                                                 []     1717312
#
#                                        ratingsByStars  likedPercent  \
# 0   ['3444695', '1921313', '745221', '171994', '93...          96.0
# 1   ['1593642', '637516', '222366', '39573', '14526']          98.0
# 4   ['1751460', '1113682', '1008686', '542017', '5...          78.0
# 5   ['1048230', '524674', '186297', '48864', '26211']          96.0
# 6   ['986764', '958699', '545475', '165093', '84682']          91.0
# 8           ['78217', '22857', '6628', '1477', '967']          98.0
# 9    ['602138', '275517', '133535', '39008', '24422']          94.0
# 12    ['556142', '204347', '94819', '27950', '22473']          94.0
# 13  ['483222', '413051', '279702', '107437', '59252']          88.0
# 15   ['712950', '615702', '295184', '66518', '26958']          95.0
#
#                                               setting  bbeScore  bbeVotes  \
# 0   ['District 12, Panem', 'Capitol, Panem', 'Pane...   2993816     30516
# 1   ['Hogwarts School of Witchcraft and Wizardry (...   2632233     26923
# 4   ['Forks, Washington (United States)', 'Phoenix...   1459448     14874
# 5                   ['Molching (Germany)', 'Germany']   1372809     14168
# 6                       ['England', 'United Kingdom']   1276599     13264
# 8                                    ['Middle-earth']   1159802     12111
# 9                ['Atlanta, Georgia (United States)']   1087732     11211
# 12                                                 []   1021534     10594
# 13                       ['Yorkshire Dales, England']    981502     10275
# 15                         ['Kyoto (Japan)', 'Japan']    862748      8993
#
#     price  Award_Count          new_genre Error_rating Error_percentage
# 0    5.09           41         YoungAdult     No_Error         No_Error
# 1    7.38            9            Fantasy     No_Error         No_Error
# 4    2.10           25         YoungAdult     No_Error         No_Error
# 5    3.80           20  HistoricalFiction     No_Error         No_Error
# 6    4.42            2           Classics     No_Error         No_Error
# 8   21.15            1            Fantasy     No_Error         No_Error
# 9    5.58            2           Classics     No_Error         No_Error
# 12   4.87            1          Childrens     No_Error         No_Error
# 13   2.73            1           Classics     No_Error         No_Error
# 15   2.76            1            Fiction     No_Error         No_Error

# %% [markdown]
# Numpy count awards

# %%
df_BestBooks['awards']
# Out:
# 0        ['Locus Award Nominee for Best Young Adult Boo...
# 1        ['Bram Stoker Award for Works for Young Reader...
# 4        ['Georgia Peach Book Award (2007)', 'Buxtehude...
# 5        ['National Jewish Book Award for Children’s an...
# 6        ['Prometheus Hall of Fame Award (2011)', 'Retr...
#                                ...
# 52470    ['HOLT Medallion by Virginia Romance Writers N...
# 52472                                                   []
# 52475              ["Readers' Favorite Book Award (2011)"]
# 52476                                                   []
# 52477                                                   []
# Name: awards, Length: 37889, dtype: object

# %%
df_BestBooks['Award_Count'] = df_BestBooks['awards'].apply(lambda n: len(n.split(',')))

# %%
df_BestBooks['Award_Count']
# Out:
# 0        41
# 1         9
# 4        25
# 5        20
# 6         2
#          ..
# 52470     1
# 52472     1
# 52475     1
# 52476     1
# 52477     1
# Name: Award_Count, Length: 37889, dtype: int64

# %%
df_BestBooks.head()
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 4                               41865.Twilight
# 5                         19063.The_Book_Thief
# 6                           170448.Animal_Farm
#
#                                        title  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 4                                   Twilight
# 5                             The Book Thief
# 6                                Animal Farm
#
#                                               author  rating           isbn  \
# 0                                    Suzanne Collins    4.33  9780439023481
# 1          J.K. Rowling, Mary GrandPré (Illustrator)    4.50  9780439358071
# 4                                    Stephenie Meyer    3.60  9780316015844
# 5                    Markus Zusak (Goodreads Author)    4.37  9780375831003
# 6  George Orwell, Russell Baker (Preface), C.M. W...    3.95  9780451526342
#
#                                               genres  \
# 0  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 4  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
# 5  ['Historical Fiction', 'Fiction', 'Young Adult...
# 6  ['Classics', 'Fiction', 'Dystopia', 'Fantasy',...
#
#                                           characters  \
# 0  ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...
# 1  ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...
# 4  ['Edward Cullen', 'Jacob Black', 'Laurent', 'R...
# 5  ['Liesel Meminger', 'Hans Hubermann', 'Rudy St...
# 6  ['Snowball', 'Napoleon', 'Clover', 'Boxer', 'O...
#
#                                               awards  numRatings  \
# 0  ['Locus Award Nominee for Best Young Adult Boo...     6376780
# 1  ['Bram Stoker Award for Works for Young Reader...     2507623
# 4  ['Georgia Peach Book Award (2007)', 'Buxtehude...     4964519
# 5  ['National Jewish Book Award for Children’s an...     1834276
# 6  ['Prometheus Hall of Fame Award (2011)', 'Retr...     2740713
#
#                                       ratingsByStars  likedPercent  \
# 0  ['3444695', '1921313', '745221', '171994', '93...          96.0
# 1  ['1593642', '637516', '222366', '39573', '14526']          98.0
# 4  ['1751460', '1113682', '1008686', '542017', '5...          78.0
# 5  ['1048230', '524674', '186297', '48864', '26211']          96.0
# 6  ['986764', '958699', '545475', '165093', '84682']          91.0
#
#                                              setting  bbeScore  bbeVotes  \
# 0  ['District 12, Panem', 'Capitol, Panem', 'Pane...   2993816     30516
# 1  ['Hogwarts School of Witchcraft and Wizardry (...   2632233     26923
# 4  ['Forks, Washington (United States)', 'Phoenix...   1459448     14874
# 5                  ['Molching (Germany)', 'Germany']   1372809     14168
# 6                      ['England', 'United Kingdom']   1276599     13264
#
#    price  Award_Count          new_genre Error_rating Error_percentage
# 0   5.09           41         YoungAdult     No_Error         No_Error
# 1   7.38            9            Fantasy     No_Error         No_Error
# 4   2.10           25         YoungAdult     No_Error         No_Error
# 5   3.80           20  HistoricalFiction     No_Error         No_Error
# 6   4.42            2           Classics     No_Error         No_Error

# %% [markdown]
# ### Split Genre list of strings so that each move is represented by the first and main genre

# %%
split_genre = df_BestBooks['genres'].str.split(',',n=1,expand=True)
split_genre.rename(columns={0:'new_genre',1:'restof_genre'})
# Out:
#                    new_genre  \
# 0             ['Young Adult'
# 1                 ['Fantasy'
# 4             ['Young Adult'
# 5      ['Historical Fiction'
# 6                ['Classics'
# ...                      ...
# 52470   ['Christian Fiction'
# 52472             ['Romance'
# 52475             ['Fantasy'
# 52476             ['Fiction'
# 52477         ['Lds Fiction'
#
#                                             restof_genre
# 0       'Fiction', 'Dystopia', 'Fantasy', 'Science Fi...
# 1       'Young Adult', 'Fiction', 'Magic', 'Childrens...
# 4       'Fantasy', 'Romance', 'Vampires', 'Fiction', ...
# 5       'Fiction', 'Young Adult', 'Historical', 'Clas...
# 6       'Fiction', 'Dystopia', 'Fantasy', 'Literature...
# ...                                                  ...
# 52470   'Christian', 'Suspense', 'Romance', 'Mystery'...
# 52472   'Young Adult', 'Contemporary', 'Contemporary ...
# 52475   'Young Adult', 'Paranormal', 'Angels', 'Roman...
# 52476   'Mystery', 'Historical Fiction', 'Adventure',...
# 52477   'Historical Fiction', 'Young Adult', 'Fiction...
#
# [37889 rows x 2 columns]

# %%
df_BestBooks[['new_genre','restof_genre']]= df_BestBooks['genres'].str.split(',',n=1,expand=True)

# %%
df_BestBooks
# Out:
#                                             bookId  \
# 0                         2767052-the-hunger-games
# 1      2.Harry_Potter_and_the_Order_of_the_Phoenix
# 4                                   41865.Twilight
# 5                             19063.The_Book_Thief
# 6                               170448.Animal_Farm
# ...                                            ...
# 52470                   11115191-attracted-to-fire
# 52472                        12395883-unbelievable
# 52475                              10815662-marked
# 52476                         11330278-wayward-son
# 52477                 10991547-daughter-of-helaman
#
#                                            title  \
# 0                               The Hunger Games
# 1      Harry Potter and the Order of the Phoenix
# 4                                       Twilight
# 5                                 The Book Thief
# 6                                    Animal Farm
# ...                                          ...
# 52470                          Attracted to Fire
# 52472                               Unbelievable
# 52475                                     Marked
# 52476                                Wayward Son
# 52477                        Daughter of Helaman
#
#                                                   author  rating  \
# 0                                        Suzanne Collins    4.33
# 1              J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 4                                        Stephenie Meyer    3.60
# 5                        Markus Zusak (Goodreads Author)    4.37
# 6      George Orwell, Russell Baker (Preface), C.M. W...    3.95
# ...                                                  ...     ...
# 52470                     DiAnn Mills (Goodreads Author)    4.14
# 52472                   Sherry Gammon (Goodreads Author)    4.16
# 52475                  Kim Richardson (Goodreads Author)    3.70
# 52476  Tom Pollack (Goodreads Author), John Loftus (G...    3.85
# 52477                    Misty Moncur (Goodreads Author)    4.02
#
#                 isbn                                             genres  \
# 0      9780439023481  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1      9780439358071  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 4      9780316015844  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
# 5      9780375831003  ['Historical Fiction', 'Fiction', 'Young Adult...
# 6      9780451526342  ['Classics', 'Fiction', 'Dystopia', 'Fantasy',...
# ...              ...                                                ...
# 52470  9781414348643  ['Christian Fiction', 'Christian', 'Suspense',...
# 52472  9781477594247  ['Romance', 'Young Adult', 'Contemporary', 'Co...
# 52475  9781461017097  ['Fantasy', 'Young Adult', 'Paranormal', 'Ange...
# 52476  9781450755634  ['Fiction', 'Mystery', 'Historical Fiction', '...
# 52477  9781599554976  ['Lds Fiction', 'Historical Fiction', 'Young A...
#
#                                               characters  \
# 0      ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...
# 1      ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...
# 4      ['Edward Cullen', 'Jacob Black', 'Laurent', 'R...
# 5      ['Liesel Meminger', 'Hans Hubermann', 'Rudy St...
# 6      ['Snowball', 'Napoleon', 'Clover', 'Boxer', 'O...
# ...                                                  ...
# 52470                                                 []
# 52472                                                 []
# 52475                                                 []
# 52476                                                 []
# 52477                                                 []
#
#                                                   awards  numRatings  \
# 0      ['Locus Award Nominee for Best Young Adult Boo...     6376780
# 1      ['Bram Stoker Award for Works for Young Reader...     2507623
# 4      ['Georgia Peach Book Award (2007)', 'Buxtehude...     4964519
# 5      ['National Jewish Book Award for Children’s an...     1834276
# 6      ['Prometheus Hall of Fame Award (2011)', 'Retr...     2740713
# ...                                                  ...         ...
# 52470  ['HOLT Medallion by Virginia Romance Writers N...        2143
# 52472                                                 []        1028
# 52475            ["Readers' Favorite Book Award (2011)"]        6674
# 52476                                                 []         238
# 52477                                                 []         246
#
#                                           ratingsByStars  likedPercent  \
# 0      ['3444695', '1921313', '745221', '171994', '93...          96.0
# 1      ['1593642', '637516', '222366', '39573', '14526']          98.0
# 4      ['1751460', '1113682', '1008686', '542017', '5...          78.0
# 5      ['1048230', '524674', '186297', '48864', '26211']          96.0
# 6      ['986764', '958699', '545475', '165093', '84682']          91.0
# ...                                                  ...           ...
# 52470                  ['945', '716', '365', '78', '39']          95.0
# 52472                  ['442', '384', '142', '48', '12']          94.0
# 52475             ['2109', '1868', '1660', '647', '390']          84.0
# 52476                      ['77', '78', '59', '19', '5']          90.0
# 52477                     ['106', '73', '42', '17', '8']          90.0
#
#                                                  setting  bbeScore  bbeVotes  \
# 0      ['District 12, Panem', 'Capitol, Panem', 'Pane...   2993816     30516
# 1      ['Hogwarts School of Witchcraft and Wizardry (...   2632233     26923
# 4      ['Forks, Washington (United States)', 'Phoenix...   1459448     14874
# 5                      ['Molching (Germany)', 'Germany']   1372809     14168
# 6                          ['England', 'United Kingdom']   1276599     13264
# ...                                                  ...       ...       ...
# 52470                     ['West Texas (United States)']         0         1
# 52472            ['Port Fare, New York (United States)']         0         1
# 52475                                                 []         0         1
# 52476                                                 []         0         1
# 52477                                                 []         0         1
#
#        price  Award_Count              new_genre Error_rating  \
# 0       5.09           41         ['Young Adult'     No_Error
# 1       7.38            9             ['Fantasy'     No_Error
# 4       2.10           25         ['Young Adult'     No_Error
# 5       3.80           20  ['Historical Fiction'     No_Error
# 6       4.42            2            ['Classics'     No_Error
# ...      ...          ...                    ...          ...
# 52470   5.55            1   ['Christian Fiction'     No_Error
# 52472  19.18            1             ['Romance'     No_Error
# 52475   7.37            1             ['Fantasy'     No_Error
# 52476   2.86            1             ['Fiction'     No_Error
# 52477   5.20            1         ['Lds Fiction'     No_Error
#
#       Error_percentage                                       restof_genre
# 0             No_Error   'Fiction', 'Dystopia', 'Fantasy', 'Science Fi...
# 1             No_Error   'Young Adult', 'Fiction', 'Magic', 'Childrens...
# 4             No_Error   'Fantasy', 'Romance', 'Vampires', 'Fiction', ...
# 5             No_Error   'Fiction', 'Young Adult', 'Historical', 'Clas...
# 6             No_Error   'Fiction', 'Dystopia', 'Fantasy', 'Literature...
# ...                ...                                                ...
# 52470         No_Error   'Christian', 'Suspense', 'Romance', 'Mystery'...
# 52472         No_Error   'Young Adult', 'Contemporary', 'Contemporary ...
# 52475         No_Error   'Young Adult', 'Paranormal', 'Angels', 'Roman...
# 52476         No_Error   'Mystery', 'Historical Fiction', 'Adventure',...
# 52477         No_Error   'Historical Fiction', 'Young Adult', 'Fiction...
#
# [37889 rows x 20 columns]

# %% [markdown]
# Remove special characters

# %%
df_BestBooks ['new_genre'] = df_BestBooks['new_genre'].str.replace(r'\W',"")
# Out:
# C:\Users\robbi\AppData\Local\Temp\ipykernel_6200\3804853204.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_BestBooks ['new_genre'] = df_BestBooks['new_genre'].str.replace(r'\W',"")

# %%
df_BestBooks.head(3)
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 4                               41865.Twilight
#
#                                        title  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 4                                   Twilight
#
#                                       author  rating           isbn  \
# 0                            Suzanne Collins    4.33  9780439023481
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50  9780439358071
# 4                            Stephenie Meyer    3.60  9780316015844
#
#                                               genres  \
# 0  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 4  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
#
#                                           characters  \
# 0  ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...
# 1  ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...
# 4  ['Edward Cullen', 'Jacob Black', 'Laurent', 'R...
#
#                                               awards  numRatings  \
# 0  ['Locus Award Nominee for Best Young Adult Boo...     6376780
# 1  ['Bram Stoker Award for Works for Young Reader...     2507623
# 4  ['Georgia Peach Book Award (2007)', 'Buxtehude...     4964519
#
#                                       ratingsByStars  likedPercent  \
# 0  ['3444695', '1921313', '745221', '171994', '93...          96.0
# 1  ['1593642', '637516', '222366', '39573', '14526']          98.0
# 4  ['1751460', '1113682', '1008686', '542017', '5...          78.0
#
#                                              setting  bbeScore  bbeVotes  \
# 0  ['District 12, Panem', 'Capitol, Panem', 'Pane...   2993816     30516
# 1  ['Hogwarts School of Witchcraft and Wizardry (...   2632233     26923
# 4  ['Forks, Washington (United States)', 'Phoenix...   1459448     14874
#
#    price  Award_Count   new_genre Error_rating Error_percentage  \
# 0   5.09           41  YoungAdult     No_Error         No_Error
# 1   7.38            9     Fantasy     No_Error         No_Error
# 4   2.10           25  YoungAdult     No_Error         No_Error
#
#                                         restof_genre
# 0   'Fiction', 'Dystopia', 'Fantasy', 'Science Fi...
# 1   'Young Adult', 'Fiction', 'Magic', 'Childrens...
# 4   'Fantasy', 'Romance', 'Vampires', 'Fiction', ...

# %%
df_BestBooks = df_BestBooks.drop(columns = ['restof_genre'])

# %%
df_BestBooks.head(3)
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 4                               41865.Twilight
#
#                                        title  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 4                                   Twilight
#
#                                       author  rating           isbn  \
# 0                            Suzanne Collins    4.33  9780439023481
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50  9780439358071
# 4                            Stephenie Meyer    3.60  9780316015844
#
#                                               genres  \
# 0  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 4  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
#
#                                           characters  \
# 0  ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...
# 1  ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...
# 4  ['Edward Cullen', 'Jacob Black', 'Laurent', 'R...
#
#                                               awards  numRatings  \
# 0  ['Locus Award Nominee for Best Young Adult Boo...     6376780
# 1  ['Bram Stoker Award for Works for Young Reader...     2507623
# 4  ['Georgia Peach Book Award (2007)', 'Buxtehude...     4964519
#
#                                       ratingsByStars  likedPercent  \
# 0  ['3444695', '1921313', '745221', '171994', '93...          96.0
# 1  ['1593642', '637516', '222366', '39573', '14526']          98.0
# 4  ['1751460', '1113682', '1008686', '542017', '5...          78.0
#
#                                              setting  bbeScore  bbeVotes  \
# 0  ['District 12, Panem', 'Capitol, Panem', 'Pane...   2993816     30516
# 1  ['Hogwarts School of Witchcraft and Wizardry (...   2632233     26923
# 4  ['Forks, Washington (United States)', 'Phoenix...   1459448     14874
#
#    price  Award_Count   new_genre Error_rating Error_percentage
# 0   5.09           41  YoungAdult     No_Error         No_Error
# 1   7.38            9     Fantasy     No_Error         No_Error
# 4   2.10           25  YoungAdult     No_Error         No_Error

# %% [markdown]
# Numpy

# %% [markdown]
# Reusable code

# %% [markdown]
# iterators

# %% [raw]
# if rating greater than 5 error, if likedPercent greater than 100 error

# %%
df_BestBooks.loc[df_BestBooks["rating"]<= 5, "Error_rating"] = "No_Error"
df_BestBooks.loc[df_BestBooks["rating"]> 5, "Error_rating"] = "Error"
df_BestBooks
# Out:
#                                             bookId  \
# 0                         2767052-the-hunger-games
# 1      2.Harry_Potter_and_the_Order_of_the_Phoenix
# 4                                   41865.Twilight
# 5                             19063.The_Book_Thief
# 6                               170448.Animal_Farm
# ...                                            ...
# 52470                   11115191-attracted-to-fire
# 52472                        12395883-unbelievable
# 52475                              10815662-marked
# 52476                         11330278-wayward-son
# 52477                 10991547-daughter-of-helaman
#
#                                            title  \
# 0                               The Hunger Games
# 1      Harry Potter and the Order of the Phoenix
# 4                                       Twilight
# 5                                 The Book Thief
# 6                                    Animal Farm
# ...                                          ...
# 52470                          Attracted to Fire
# 52472                               Unbelievable
# 52475                                     Marked
# 52476                                Wayward Son
# 52477                        Daughter of Helaman
#
#                                                   author  rating  \
# 0                                        Suzanne Collins    4.33
# 1              J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 4                                        Stephenie Meyer    3.60
# 5                        Markus Zusak (Goodreads Author)    4.37
# 6      George Orwell, Russell Baker (Preface), C.M. W...    3.95
# ...                                                  ...     ...
# 52470                     DiAnn Mills (Goodreads Author)    4.14
# 52472                   Sherry Gammon (Goodreads Author)    4.16
# 52475                  Kim Richardson (Goodreads Author)    3.70
# 52476  Tom Pollack (Goodreads Author), John Loftus (G...    3.85
# 52477                    Misty Moncur (Goodreads Author)    4.02
#
#                 isbn                                             genres  \
# 0      9780439023481  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1      9780439358071  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 4      9780316015844  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
# 5      9780375831003  ['Historical Fiction', 'Fiction', 'Young Adult...
# 6      9780451526342  ['Classics', 'Fiction', 'Dystopia', 'Fantasy',...
# ...              ...                                                ...
# 52470  9781414348643  ['Christian Fiction', 'Christian', 'Suspense',...
# 52472  9781477594247  ['Romance', 'Young Adult', 'Contemporary', 'Co...
# 52475  9781461017097  ['Fantasy', 'Young Adult', 'Paranormal', 'Ange...
# 52476  9781450755634  ['Fiction', 'Mystery', 'Historical Fiction', '...
# 52477  9781599554976  ['Lds Fiction', 'Historical Fiction', 'Young A...
#
#                                               characters  \
# 0      ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...
# 1      ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...
# 4      ['Edward Cullen', 'Jacob Black', 'Laurent', 'R...
# 5      ['Liesel Meminger', 'Hans Hubermann', 'Rudy St...
# 6      ['Snowball', 'Napoleon', 'Clover', 'Boxer', 'O...
# ...                                                  ...
# 52470                                                 []
# 52472                                                 []
# 52475                                                 []
# 52476                                                 []
# 52477                                                 []
#
#                                                   awards  numRatings  \
# 0      ['Locus Award Nominee for Best Young Adult Boo...     6376780
# 1      ['Bram Stoker Award for Works for Young Reader...     2507623
# 4      ['Georgia Peach Book Award (2007)', 'Buxtehude...     4964519
# 5      ['National Jewish Book Award for Children’s an...     1834276
# 6      ['Prometheus Hall of Fame Award (2011)', 'Retr...     2740713
# ...                                                  ...         ...
# 52470  ['HOLT Medallion by Virginia Romance Writers N...        2143
# 52472                                                 []        1028
# 52475            ["Readers' Favorite Book Award (2011)"]        6674
# 52476                                                 []         238
# 52477                                                 []         246
#
#                                           ratingsByStars  likedPercent  \
# 0      ['3444695', '1921313', '745221', '171994', '93...          96.0
# 1      ['1593642', '637516', '222366', '39573', '14526']          98.0
# 4      ['1751460', '1113682', '1008686', '542017', '5...          78.0
# 5      ['1048230', '524674', '186297', '48864', '26211']          96.0
# 6      ['986764', '958699', '545475', '165093', '84682']          91.0
# ...                                                  ...           ...
# 52470                  ['945', '716', '365', '78', '39']          95.0
# 52472                  ['442', '384', '142', '48', '12']          94.0
# 52475             ['2109', '1868', '1660', '647', '390']          84.0
# 52476                      ['77', '78', '59', '19', '5']          90.0
# 52477                     ['106', '73', '42', '17', '8']          90.0
#
#                                                  setting  bbeScore  bbeVotes  \
# 0      ['District 12, Panem', 'Capitol, Panem', 'Pane...   2993816     30516
# 1      ['Hogwarts School of Witchcraft and Wizardry (...   2632233     26923
# 4      ['Forks, Washington (United States)', 'Phoenix...   1459448     14874
# 5                      ['Molching (Germany)', 'Germany']   1372809     14168
# 6                          ['England', 'United Kingdom']   1276599     13264
# ...                                                  ...       ...       ...
# 52470                     ['West Texas (United States)']         0         1
# 52472            ['Port Fare, New York (United States)']         0         1
# 52475                                                 []         0         1
# 52476                                                 []         0         1
# 52477                                                 []         0         1
#
#        price  Award_Count          new_genre Error_rating Error_percentage
# 0       5.09           41         YoungAdult     No_Error         No_Error
# 1       7.38            9            Fantasy     No_Error         No_Error
# 4       2.10           25         YoungAdult     No_Error         No_Error
# 5       3.80           20  HistoricalFiction     No_Error         No_Error
# 6       4.42            2           Classics     No_Error         No_Error
# ...      ...          ...                ...          ...              ...
# 52470   5.55            1   ChristianFiction     No_Error         No_Error
# 52472  19.18            1            Romance     No_Error         No_Error
# 52475   7.37            1            Fantasy     No_Error         No_Error
# 52476   2.86            1            Fiction     No_Error         No_Error
# 52477   5.20            1         LdsFiction     No_Error         No_Error
#
# [37889 rows x 19 columns]

# %%
df_BestBooks['Error_rating'].value_counts()
# Out:
# No_Error    37889
# Name: Error_rating, dtype: int64

# %%
print(df_BestBooks.Error_rating)
# Out:
# 0        No_Error
# 1        No_Error
# 4        No_Error
# 5        No_Error
# 6        No_Error
#            ...
# 52470    No_Error
# 52472    No_Error
# 52475    No_Error
# 52476    No_Error
# 52477    No_Error
# Name: Error_rating, Length: 37889, dtype: object

# %%
df_BestBooks.loc[df_BestBooks["likedPercent"]<= 100, "Error_percentage"] = "No_Error"
df_BestBooks.loc[df_BestBooks["likedPercent"]> 100, "Error_percentage"] = "Error"
df_BestBooks
# Out:
#                                             bookId  \
# 0                         2767052-the-hunger-games
# 1      2.Harry_Potter_and_the_Order_of_the_Phoenix
# 4                                   41865.Twilight
# 5                             19063.The_Book_Thief
# 6                               170448.Animal_Farm
# ...                                            ...
# 52470                   11115191-attracted-to-fire
# 52472                        12395883-unbelievable
# 52475                              10815662-marked
# 52476                         11330278-wayward-son
# 52477                 10991547-daughter-of-helaman
#
#                                            title  \
# 0                               The Hunger Games
# 1      Harry Potter and the Order of the Phoenix
# 4                                       Twilight
# 5                                 The Book Thief
# 6                                    Animal Farm
# ...                                          ...
# 52470                          Attracted to Fire
# 52472                               Unbelievable
# 52475                                     Marked
# 52476                                Wayward Son
# 52477                        Daughter of Helaman
#
#                                                   author  rating  \
# 0                                        Suzanne Collins    4.33
# 1              J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 4                                        Stephenie Meyer    3.60
# 5                        Markus Zusak (Goodreads Author)    4.37
# 6      George Orwell, Russell Baker (Preface), C.M. W...    3.95
# ...                                                  ...     ...
# 52470                     DiAnn Mills (Goodreads Author)    4.14
# 52472                   Sherry Gammon (Goodreads Author)    4.16
# 52475                  Kim Richardson (Goodreads Author)    3.70
# 52476  Tom Pollack (Goodreads Author), John Loftus (G...    3.85
# 52477                    Misty Moncur (Goodreads Author)    4.02
#
#                 isbn                                             genres  \
# 0      9780439023481  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1      9780439358071  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 4      9780316015844  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
# 5      9780375831003  ['Historical Fiction', 'Fiction', 'Young Adult...
# 6      9780451526342  ['Classics', 'Fiction', 'Dystopia', 'Fantasy',...
# ...              ...                                                ...
# 52470  9781414348643  ['Christian Fiction', 'Christian', 'Suspense',...
# 52472  9781477594247  ['Romance', 'Young Adult', 'Contemporary', 'Co...
# 52475  9781461017097  ['Fantasy', 'Young Adult', 'Paranormal', 'Ange...
# 52476  9781450755634  ['Fiction', 'Mystery', 'Historical Fiction', '...
# 52477  9781599554976  ['Lds Fiction', 'Historical Fiction', 'Young A...
#
#                                               characters  \
# 0      ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...
# 1      ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...
# 4      ['Edward Cullen', 'Jacob Black', 'Laurent', 'R...
# 5      ['Liesel Meminger', 'Hans Hubermann', 'Rudy St...
# 6      ['Snowball', 'Napoleon', 'Clover', 'Boxer', 'O...
# ...                                                  ...
# 52470                                                 []
# 52472                                                 []
# 52475                                                 []
# 52476                                                 []
# 52477                                                 []
#
#                                                   awards  numRatings  \
# 0      ['Locus Award Nominee for Best Young Adult Boo...     6376780
# 1      ['Bram Stoker Award for Works for Young Reader...     2507623
# 4      ['Georgia Peach Book Award (2007)', 'Buxtehude...     4964519
# 5      ['National Jewish Book Award for Children’s an...     1834276
# 6      ['Prometheus Hall of Fame Award (2011)', 'Retr...     2740713
# ...                                                  ...         ...
# 52470  ['HOLT Medallion by Virginia Romance Writers N...        2143
# 52472                                                 []        1028
# 52475            ["Readers' Favorite Book Award (2011)"]        6674
# 52476                                                 []         238
# 52477                                                 []         246
#
#                                           ratingsByStars  likedPercent  \
# 0      ['3444695', '1921313', '745221', '171994', '93...          96.0
# 1      ['1593642', '637516', '222366', '39573', '14526']          98.0
# 4      ['1751460', '1113682', '1008686', '542017', '5...          78.0
# 5      ['1048230', '524674', '186297', '48864', '26211']          96.0
# 6      ['986764', '958699', '545475', '165093', '84682']          91.0
# ...                                                  ...           ...
# 52470                  ['945', '716', '365', '78', '39']          95.0
# 52472                  ['442', '384', '142', '48', '12']          94.0
# 52475             ['2109', '1868', '1660', '647', '390']          84.0
# 52476                      ['77', '78', '59', '19', '5']          90.0
# 52477                     ['106', '73', '42', '17', '8']          90.0
#
#                                                  setting  bbeScore  bbeVotes  \
# 0      ['District 12, Panem', 'Capitol, Panem', 'Pane...   2993816     30516
# 1      ['Hogwarts School of Witchcraft and Wizardry (...   2632233     26923
# 4      ['Forks, Washington (United States)', 'Phoenix...   1459448     14874
# 5                      ['Molching (Germany)', 'Germany']   1372809     14168
# 6                          ['England', 'United Kingdom']   1276599     13264
# ...                                                  ...       ...       ...
# 52470                     ['West Texas (United States)']         0         1
# 52472            ['Port Fare, New York (United States)']         0         1
# 52475                                                 []         0         1
# 52476                                                 []         0         1
# 52477                                                 []         0         1
#
#        price  Award_Count          new_genre Error_rating Error_percentage
# 0       5.09           41         YoungAdult     No_Error         No_Error
# 1       7.38            9            Fantasy     No_Error         No_Error
# 4       2.10           25         YoungAdult     No_Error         No_Error
# 5       3.80           20  HistoricalFiction     No_Error         No_Error
# 6       4.42            2           Classics     No_Error         No_Error
# ...      ...          ...                ...          ...              ...
# 52470   5.55            1   ChristianFiction     No_Error         No_Error
# 52472  19.18            1            Romance     No_Error         No_Error
# 52475   7.37            1            Fantasy     No_Error         No_Error
# 52476   2.86            1            Fiction     No_Error         No_Error
# 52477   5.20            1         LdsFiction     No_Error         No_Error
#
# [37889 rows x 19 columns]

# %%
df_BestBooks['Error_percentage'].value_counts()
# Out:
# No_Error    37889
# Name: Error_percentage, dtype: int64

# %% [markdown]
# Data types

# %%
print(df_BestBooks.likedPercent.dtypes)   
print(df_BestBooks.price.dtypes)
# Out:
# float64
# float64

# %% [markdown]
# Convert price to int - previous..

# %%
df_BestBooks['price'] = pd.to_numeric(df_BestBooks['price'], errors='coerce')
print(df_BestBooks.price.dtypes)
# Out:
# float64

# %% [markdown]
# Define x and y

# %%
X = df_BestBooks['likedPercent'].values
y = df_BestBooks['rating'].values

# %%
X
# Out:
# array([96., 98., 78., ..., 84., 90., 90.])

# %% [markdown]
# Need to reshape

# %%
X = X.reshape(-1,1)
y = y.reshape (-1,1)

# %%
X
# Out:
# array([[96.],
#        [98.],
#        [78.],
#        ...,
#        [84.],
#        [90.],
#        [90.]])

# %%
y
# Out:
# array([[4.33],
#        [4.5 ],
#        [3.6 ],
#        ...,
#        [3.7 ],
#        [3.85],
#        [4.02]])

# %% [markdown]
# Split the dataset into training data and testing data - 70/30

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y, test_size=0.2, random_state=0)

# %%
X_train,X_test,y_train,y_test
# Out:
# (array([[94.],
#         [97.],
#         [91.],
#         ...,
#         [96.],
#         [89.],
#         [93.]]),
#  array([[96.],
#         [92.],
#         [87.],
#         ...,
#         [96.],
#         [92.],
#         [97.]]),
#  array([[4.08],
#         [4.06],
#         [4.  ],
#         ...,
#         [3.9 ],
#         [3.68],
#         [3.88]]),
#  array([[4.32],
#         [3.97],
#         [3.61],
#         ...,
#         [4.5 ],
#         [3.89],
#         [4.36]]))

# %% [markdown]
# Make a function for regression as reg and fit the model with our split dataset

# %%
reg= LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Test (predict) the output for the test data using the fitted model

# %%
y_predict=reg.predict(X_test)
print(y_predict)
print(y_test)
# Out:
# [[4.16690385]
#  [3.98422188]
#  [3.75586941]
#  ...
#  [4.16690385]
#  [3.98422188]
#  [4.21257434]]
# [[4.32]
#  [3.97]
#  [3.61]
#  ...
#  [4.5 ]
#  [3.89]
#  [4.36]]

# %% [markdown]
# Determine the performance of the model using coefficent of determination

# %%
print('Coefficent of determination: %.3f' % r2_score(y_test,y_predict))
# Out:
# Coefficent of determination: 0.682

# %% [markdown]
# Hyperparameter tuning

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y, test_size=0.2, random_state=0)

# %%
X_train,X_test,y_train,y_test
# Out:
# (array([[94.],
#         [97.],
#         [91.],
#         ...,
#         [96.],
#         [89.],
#         [93.]]),
#  array([[96.],
#         [92.],
#         [87.],
#         ...,
#         [96.],
#         [92.],
#         [97.]]),
#  array([[4.08],
#         [4.06],
#         [4.  ],
#         ...,
#         [3.9 ],
#         [3.68],
#         [3.88]]),
#  array([[4.32],
#         [3.97],
#         [3.61],
#         ...,
#         [4.5 ],
#         [3.89],
#         [4.36]]))

# %%
reg2= LinearRegression()
reg2.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=reg2.predict(X_test)
print(y_predict)
print(y_test)
# Out:
# [[4.16690385]
#  [3.98422188]
#  [3.75586941]
#  ...
#  [4.16690385]
#  [3.98422188]
#  [4.21257434]]
# [[4.32]
#  [3.97]
#  [3.61]
#  ...
#  [4.5 ]
#  [3.89]
#  [4.36]]

# %%
print('Coefficent of determination: %.3f' % r2_score(y_test,y_predict))
# Out:
# Coefficent of determination: 0.682

# %% [markdown]
# Visualisation - Graph (MatPlotLib)

# %%
plt.scatter(X_train,y_train,color='red')
plt.plot(X_train,reg.predict(X_train),color='blue')
plt.title("Liked Percentage V's Rating")
plt.xlabel("Liked Percent out of 100")
plt.ylabel("Rating out of 5")
plt.show()

# %% [markdown]
# predict for test

# %%
plt.scatter(X_test,y_test,color='red')
plt.plot(X_test,reg.predict(X_test),color='blue')
plt.title("Linear Regression liked % V's Rating")
plt.xlabel("Price")
plt.ylabel("Rating out of 5")
plt.show()

# %% [markdown]
# https://www.kaggle.com/datasets/shashwatwork/best-book-ever-data-for-2021

# %% [markdown]
# A book’s total score is based on multiple factors, including the number of people who have voted for it and how highly those voters ranked the book.

# %% [markdown]
# https://www.youtube.com/watch?v=Ge0z9_sywho
#
# https://www.youtube.com/results?search_query=machine+learning+data+science+linear+regression+jupyter+notebook
#
# https://github.com/scostap/goodreads_bbe_dataset
